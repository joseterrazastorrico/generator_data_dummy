# %%
import pandas as pd
import random

# %%
data = pd.read_parquet('prueba.parquet')
data.loc[data.status_running==0] = 0
data.head()
# Out:
#                              tph  status_running  concentracion arcilla  \
# 2025-01-01T00:00:00  7429.218127               1              22.493978
# 2025-01-01T01:00:00  7280.983463               1              22.027492
# 2025-01-01T02:00:00  6779.039341               1              23.424014
# 2025-01-01T03:00:00  7550.532156               1              25.718165
# 2025-01-01T04:00:00  7725.778374               1              23.208916
#
#                       cu_alim  recuperacion_rougher
# 2025-01-01T00:00:00  1.189726             86.319881
# 2025-01-01T01:00:00  0.969759             83.566478
# 2025-01-01T02:00:00  0.819910             87.082121
# 2025-01-01T03:00:00  1.003435             89.565500
# 2025-01-01T04:00:00  0.899499             80.102836

# %%
data.loc[data.status_running==1].cu_alim.mean()
# Out:
# 0.9291195229979151

# %%
data.tph.plot()
# Out:
# <Axes: >
